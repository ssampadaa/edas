# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# here:importing necessary libraries

# %%
df= pd.read_csv('country_wise_latest.csv')

# %% [markdown]
# here:reading data sets value

# %%
df.head(20)
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# 5   Antigua and Barbuda         86       3         65      18          4
# 6             Argentina     167416    3059      72575   91782       4890
# 7               Armenia      37390     711      26665   10014         73
# 8             Australia      15303     167       9311    5825        368
# 9               Austria      20558     713      18246    1599         86
# 10           Azerbaijan      30446     423      23242    6781        396
# 11              Bahamas        382      11         91     280         40
# ...

# %% [markdown]
# here:showing first 20 elements of the data set

# %%
df.tail(20)
# Out:
#            Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 167              Thailand       3297      58       3111      128          6
# 168           Timor-Leste         24       0          0       24          0
# 169                  Togo        874      18        607      249          6
# 170   Trinidad and Tobago        148       8        128       12          1
# 171               Tunisia       1455      50       1157      248          3
# 172                Turkey     227019    5630     210469    10920        919
# 173                    US    4290259  148011    1325804  2816444      56336
# 174                Uganda       1128       2        986      140         13
# 175               Ukraine      67096    1636      37202    28258        835
# 176  United Arab Emirates      59177     345      52510     6322        264
# 177        United Kingdom     301708   45844       1437   254427        688
# ...

# %% [markdown]
# here:showing last 20 elements of the data set

# %%
df.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# ...

# %% [markdown]
# here:
# number of country affected is 187
# mean of deaths is 3497
# maximum death is 148011
# mean of new cases is 1222
# maximum new cases is 56336
# mean of new deaths is 28.95
# maximum new deaths is 1076
# mean of 100 death cases is 3
# maximum deaths out of 100 cases is 28.6
# mean of recovered cases is 64.8
# maximum recovered out of 100 cases is 100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %% [markdown]
# here:
# integers type,object type and float type of the features are shown

# %%
sns.histplot(x=df['Deaths / 100 Cases'],kde=False,
             bins=8,color='green',
             )
# Out:
# <Axes: xlabel='Deaths / 100 Cases', ylabel='Count'>

# %% [markdown]
# here:s
# from the above histogram we can see the distribution of Deaths / 100 Cases on X-axis and count on Y-axis

# %%
sns.scatterplot(x=df['Deaths / 100 Cases'], y=df['Recovered / 100 Cases'])
# Out:
# <Axes: xlabel='Deaths / 100 Cases', ylabel='Recovered / 100 Cases'>

# %% [markdown]
# here:
# scatterplot between Deaths / 100 Cases and Recovered / 100 Cases is shown
# as the number of recovered cases is increasing number of deaths are decreasing

# %%
sns.lineplot(x='Deaths',y='Recovered', data=df )
# Out:
# <Axes: xlabel='Deaths', ylabel='Recovered'>

# %%
sns.histplot(y=df['WHO Region'],kde=False,
             bins=6,color='blue',
             )
# Out:
# <Axes: xlabel='Count', ylabel='WHO Region'>

# %% [markdown]
# here:
# graph of WHO region and count is shown
# we can see most WHO region lies in Europe
# we can also see WHO regiron lies least in south-east asia

# %%
sns.relplot(data=df, x="1 week change",y="New cases",kind="line")
